# %%
from dotenv import load_dotenv
load_dotenv()
from anthropic import Anthropic
client = Anthropic()
model="claude-haiku-4-5-20251001"
def add_user_message(messages,text):
    messages.append({"role": "user", "content": text})
def add_assistant_message(messages,text):
    messages.append({"role": "assistant", "content": text})
def chat(messages,system=None):
    params={
        "max_tokens" :1024,
        "model" : model,
        "messages" : messages,
    }
    if system :
        params["system"] = system
    response = client.messages.create(**params)
    return response.content[0].text

# %%
messages=[]
system_prompt="""You are a patient math tutor. Do not directly answer as student's 
questions. Guide them to a solution step by step."""
add_user_message(messages,"How do i solve 5x+3=2 for x?")
answer=chat(messages,system=system_prompt)
answer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       1 messages=[]
#       2 system_prompt="""You are a patient math tutor. Do not directly answer as student's
#       3 questions. Guide them to a solution step by step."""
#       4 add_user_message(messages,"How do i solve 5x+3=2 for x?")
# ----> 5 answer=chat(messages,system=system_prompt)
#       6 answer
#
# Cell In[14], line 18, in chat(messages, system)
#      14         "messages" : messages,
#      15     }
#      16     if system :
#      17         params[system] = system
# ---> 18     response = client.messages.create(**params)
#      19     return response.content[0].text
#
# File ~/ccaf/anthropic-training-exercises/.venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# TypeError: Messages.create() got an unexpected keyword argument 'You are a patient math tutor. Do not directly answer as student's
# questions. Guide them to a solution step by step.'
